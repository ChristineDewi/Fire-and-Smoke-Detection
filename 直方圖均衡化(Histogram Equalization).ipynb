# %%
import cv2
import numpy as np
class1=[347,378,355,385,341,346,410,345,388,370,379,355]
# img = cv2.imread('img/label1-1.jpg')

# img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

# # equalize the histogram of the Y channel
# img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

# # convert the YUV image back to RGB format
# img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)

# # cv2.imshow('Color input image', img)
# # cv2.imshow('Histogram equalized', img_output)
# cv.imwrite('CLAHE/label'+str(i)+'-'+str(j)+'.jpg', img_output)
# print('img/label'+str(i)+'-'+str(j)+'.jpg')
# cv2.waitKey(0)



for i in range(3,13,1):
    c=class1[i-1]
    for j in range(1,c,1):
        img = cv2.imread('img/label'+str(i)+'-'+str(j)+'.jpg')
        img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
        img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])
        img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
        cv2.imwrite('HE/label'+str(i)+'-'+str(j)+'.jpg', img_output)
        print('img/label'+str(i)+'-'+str(j)+'.jpg')
# Out:
# img/label3-1.jpg
# img/label3-2.jpg
# img/label3-3.jpg
# img/label3-4.jpg
# img/label3-5.jpg
# img/label3-6.jpg
# img/label3-7.jpg
# img/label3-8.jpg
# img/label3-9.jpg
# img/label3-10.jpg
# img/label3-11.jpg
# img/label3-12.jpg
# img/label3-13.jpg
# img/label3-14.jpg
# img/label3-15.jpg
# img/label3-16.jpg
# img/label3-17.jpg
# img/label3-18.jpg
# img/label3-19.jpg
# img/label3-20.jpg
# img/label3-21.jpg
# img/label3-22.jpg
# img/label3-23.jpg
# img/label3-24.jpg
# img/label3-25.jpg
# img/label3-26.jpg
# img/label3-27.jpg
# img/label3-28.jpg
# img/label3-29.jpg
# img/label3-30.jpg
# img/label3-31.jpg
# img/label3-32.jpg
# img/label3-33.jpg
# img/label3-34.jpg
# img/label3-35.jpg
# img/label3-36.jpg
# img/label3-37.jpg
# img/label3-38.jpg
# img/label3-39.jpg
# img/label3-40.jpg
# img/label3-41.jpg
# img/label3-42.jpg
# img/label3-43.jpg
# img/label3-44.jpg
# img/label3-45.jpg
# img/label3-46.jpg
# img/label3-47.jpg
# img/label3-48.jpg
# img/label3-49.jpg
# img/label3-50.jpg
# ...

# %%
import cv2
import numpy as np

img = cv2.imread('')

img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

# equalize the histogram of the Y channel
img_yuv[:,:,0] = cv2.equalizeHist(img_yuv[:,:,0])

# convert the YUV image back to RGB format
img_output = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)

# cv2.imshow('Color input image', img)
# cv2.imshow('Histogram equalized', img_output)
cv.imwrite('CLAHE/label'+str(i)+'-'+str(j)+'.jpg', img_output)
print('img/label'+str(i)+'-'+str(j)+'.jpg')
cv2.waitKey(0)
