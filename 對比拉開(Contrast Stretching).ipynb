# %%
# #import libraries files

# from skimage import io
# from skimage import color
# from skimage import data
# from pylab import *

# #load image
# img = io.imread("img/label1-1.jpg")

# #rgb2yuv converting

# img_yuv = color.rgb2yuv(img)

# #yuv2rgb converting

# img_rgb = color.yuv2rgb(img_yuv)


# #show the both figure

# figure(0)

# io.imshow(img_yuv)

# figure(1)

# io.imshow(img_rgb)

# figure(2)

# io.imshow(img)


import cv2
import numpy as np
class1=[347,378,355,385,341,346,410,345,388,370,379,355]
# img = cv2.imread("img/label1-1.jpg")
# original = img.copy()
# xp = [0, 64, 128, 192, 255]
# fp = [0, 16, 128, 240, 255]
# x = np.arange(256)
# table = np.interp(x, xp, fp).astype('uint8')
# img2 = cv2.LUT(img, table)
# cv2.imshow("original", original)
# cv2.imshow("Output", img2)
# cv2.waitKey(0)
# cv2.destroyAllWindows() 


for i in range(3,13,1):
    c=class1[i-1]
    for j in range(1,c,1):
        img = cv2.imread('img/label'+str(i)+'-'+str(j)+'.jpg')
        original = img.copy()
        xp = [0, 64, 128, 192, 255]
        fp = [0, 16, 128, 240, 255]
        x = np.arange(256)
        table = np.interp(x, xp, fp).astype('uint8')
        img2 = cv2.LUT(img, table)
        cv2.imwrite('CS/label'+str(i)+'-'+str(j)+'.jpg', img2)
        print('CS/label'+str(i)+'-'+str(j)+'.jpg')
# Out:
# CS/label3-1.jpg
# CS/label3-2.jpg
# CS/label3-3.jpg
# CS/label3-4.jpg
# CS/label3-5.jpg
# CS/label3-6.jpg
# CS/label3-7.jpg
# CS/label3-8.jpg
# CS/label3-9.jpg
# CS/label3-10.jpg
# CS/label3-11.jpg
# CS/label3-12.jpg
# CS/label3-13.jpg
# CS/label3-14.jpg
# CS/label3-15.jpg
# CS/label3-16.jpg
# CS/label3-17.jpg
# CS/label3-18.jpg
# CS/label3-19.jpg
# CS/label3-20.jpg
# CS/label3-21.jpg
# CS/label3-22.jpg
# CS/label3-23.jpg
# CS/label3-24.jpg
# CS/label3-25.jpg
# CS/label3-26.jpg
# CS/label3-27.jpg
# CS/label3-28.jpg
# CS/label3-29.jpg
# CS/label3-30.jpg
# CS/label3-31.jpg
# CS/label3-32.jpg
# CS/label3-33.jpg
# CS/label3-34.jpg
# CS/label3-35.jpg
# CS/label3-36.jpg
# CS/label3-37.jpg
# CS/label3-38.jpg
# CS/label3-39.jpg
# CS/label3-40.jpg
# CS/label3-41.jpg
# CS/label3-42.jpg
# CS/label3-43.jpg
# CS/label3-44.jpg
# CS/label3-45.jpg
# CS/label3-46.jpg
# CS/label3-47.jpg
# CS/label3-48.jpg
# CS/label3-49.jpg
# CS/label3-50.jpg
# CS/label3-51.jpg
# CS/label3-52.jpg
# CS/label3-53.jpg
# ...

# %%
import cv2
import numpy as np

img = cv2.imread("")
original = img.copy()
xp = [0, 64, 128, 192, 255]
fp = [0, 16, 128, 240, 255]
x = np.arange(256)
table = np.interp(x, xp, fp).astype('uint8')
img2 = cv2.LUT(img, table)
cv2.imshow("original", original)
cv2.imshow("Output", img2)
cv2.waitKey(0)
cv2.destroyAllWindows() 

class1=[347,378,355,385,341,346,410,345,388,370,379,355]

for i in range(3,13,1):
    c=class1[i-1]
    for j in range(1,c,1):
        img = cv2.imread('img/label'+str(i)+'-'+str(j)+'.jpg')
        original = img.copy()
        xp = [0, 64, 128, 192, 255]
        fp = [0, 16, 128, 240, 255]
        x = np.arange(256)
        table = np.interp(x, xp, fp).astype('uint8')
        img2 = cv2.LUT(img, table)
        cv2.imwrite('CS/label'+str(i)+'-'+str(j)+'.jpg', img2)
        print('CS/label'+str(i)+'-'+str(j)+'.jpg')
